# %%
import pandas as pd 
# Load the new dataset and display its first few rows to understand its structure
new_data_path = 'params_study2_retest_rt_acc_quartiles.csv'
new_data = pd.read_csv(new_data_path)

new_data.head()
# Out:
#    Unnamed: 0                           Experiment   v1_mean   v2_mean  \
# 0           0  1010_associative_priming_part_2.dat  1.317769  0.958077
# 1           1  2013_associative_priming_part_2.dat  1.702712  2.524507
# 2           2  4010_associative_priming_part_2.dat  2.228414  2.384824
# 3           3  4006_associative_priming_part_1.dat  2.212530  2.440425
# 4           4  1001_associative_priming_part_2.dat  2.583658  2.421285
#
#     v3_mean   v4_mean   zr_mean    a_mean  ndt1_mean  ndt2_mean  ...  \
# 0 -1.693417 -1.385395  0.490391  0.858454   0.548514   0.577642  ...
# 1 -2.312126 -2.225672  0.482890  1.011613   0.500935   0.553446  ...
# 2 -2.528669 -2.586009  0.496064  1.445829   0.550784   0.532012  ...
# 3 -3.128784 -2.787327  0.480563  1.345490   0.491984   0.507506  ...
# 4 -3.796118 -3.182435  0.604069  1.267974   0.531594   0.530417  ...
#
#                                          error_array  \
# 0  32     1.172\n48     0.790\n56     0.655\n57  ...
# ...

# %%
list(new_data)
# Out:
# ['Unnamed: 0',
#  'Experiment',
#  'v1_mean',
#  'v2_mean',
#  'v3_mean',
#  'v4_mean',
#  'zr_mean',
#  'a_mean',
#  'ndt1_mean',
#  'ndt2_mean',
#  'ndt3_mean',
#  'ndt4_mean',
#  'sndt_mean',
#  'alpha_mean',
#  'accuracy_percentage',
#  'mean_log_rt',
#  'RT_mean_correct_error',
#  'mean_correct',
#  'mean_Crror',
#  'error_array',
#  'RT_Cor_arr',
#  'q1_C',
#  'q2_C',
#  'q3_C',
#  'q4_C',
#  'q1_E',
#  'q2_E',
#  'q3_E',
#  'q4_E']

# %%
# Extract subject_id, task, and session from 'Experiment' column
new_data['subject_id'] = new_data['Experiment'].str.extract(r'(\d+)_').astype(int)
new_data['session'] = new_data['Experiment'].str.extract(r'_(part_\d)').astype(str)

# Now let's split the data into the four categories we are interested in
# For the Lexical Decision Task (LDT)
ldt_part_1_data_new = new_data[(new_data['session'] == 'part_1')]
ldt_part_2_data_new = new_data[(new_data['session'] == 'part_2')]



# Check if the splits are correctly done by displaying the head of each
(ldt_part_1_data_new.head(), ldt_part_2_data_new.head())
# Out:
# (   Unnamed: 0                           Experiment   v1_mean   v2_mean  \
#  3           3  4006_associative_priming_part_1.dat  2.212530  2.440425
#  6           6  1002_associative_priming_part_1.dat  1.670991  1.528863
#  7           7  2029_associative_priming_part_1.dat  2.310502  2.557981
#  8           8  1022_associative_priming_part_1.dat  1.288836  1.481549
#  9           9  3005_associative_priming_part_1.dat  1.432452  1.575278
#
#      v3_mean   v4_mean   zr_mean    a_mean  ndt1_mean  ndt2_mean  ...  \
#  3 -3.128784 -2.787327  0.480563  1.345490   0.491984   0.507506  ...
#  6 -2.223166 -2.360074  0.583722  1.484140   0.571052   0.575191  ...
#  7 -2.237449 -2.551819  0.487476  1.340029   0.555182   0.580580  ...
#  8 -1.566155 -2.042481  0.495662  1.366666   0.528929   0.550522  ...
#  9 -2.510510 -1.925811  0.535740  1.121483   0.539331   0.573526  ...
#
#                                                  q3_C  \
# ...

# %%
# Investigate the unique values in the 'task' and 'session' columns to correct the filtering
unique_sessions = new_data['session'].unique()

unique_sessions
# Out:
# array(['part_2', 'part_1'], dtype=object)

# %%
# Correct parsing of the 'task' column to separate the 'class' and 'part' correctly
new_data['class'] = new_data['Experiment'].str.extract(r'class_(\w+)')

# Now let's split the data into the four categories we are interested in again
# For the Lexical Decision Task (LDT)
ldt_part_1_data_new = new_data[(new_data['class'] == 'words') & (new_data['session'] == 'part_1')]
ldt_part_2_data_new = new_data[(new_data['class'] == 'words') & (new_data['session'] == 'part_2')]

# For the Recognition Memory Task (RMT)
rmt_part_1_data_new = new_data[(new_data['class'] == 'pictures') & (new_data['session'] == 'part_1')]
rmt_part_2_data_new = new_data[(new_data['class'] == 'pictures') & (new_data['session'] == 'part_2')]

# Check if the splits are correctly done by displaying the head of each
(ldt_part_1_data_new.head(), ldt_part_2_data_new.head(), rmt_part_1_data_new.head(), rmt_part_2_data_new.head())
# Out:
# (Empty DataFrame
#  Columns: [Unnamed: 0, Experiment, v1_mean, v2_mean, v3_mean, v4_mean, zr_mean, a_mean, ndt1_mean, ndt2_mean, ndt3_mean, ndt4_mean, sndt_mean, alpha_mean, accuracy_percentage, mean_log_rt, RT_mean_correct_error, mean_correct, mean_Crror, error_array, RT_Cor_arr, q1_C, q2_C, q3_C, q4_C, q1_E, q2_E, q3_E, q4_E, subject_id, task, session, class]
#  Index: []
#
#  [0 rows x 33 columns],
#  Empty DataFrame
#  Columns: [Unnamed: 0, Experiment, v1_mean, v2_mean, v3_mean, v4_mean, zr_mean, a_mean, ndt1_mean, ndt2_mean, ndt3_mean, ndt4_mean, sndt_mean, alpha_mean, accuracy_percentage, mean_log_rt, RT_mean_correct_error, mean_correct, mean_Crror, error_array, RT_Cor_arr, q1_C, q2_C, q3_C, q4_C, q1_E, q2_E, q3_E, q4_E, subject_id, task, session, class]
#  Index: []
#
#  [0 rows x 33 columns],
#  Empty DataFrame
# ...
