# %%
import pandas as pd 
data = pd.read_csv('ldt_session_1_data_transformed.csv')

# %%
data
# Out:
#      Unnamed: 0                           Experiment   v1_mean   v2_mean  \
# 0             3  4006_associative_priming_part_1.dat  2.218206  2.466012
# 1             6  1002_associative_priming_part_1.dat  1.681164  1.521526
# 2             7  2029_associative_priming_part_1.dat  2.303126  2.534441
# 3             8  1022_associative_priming_part_1.dat  1.281966  1.480884
# 4             9  3005_associative_priming_part_1.dat  1.441904  1.572430
# ..          ...                                  ...       ...       ...
# 123         243  3032_associative_priming_part_1.dat  1.852661  2.163971
# 124         245  2024_associative_priming_part_1.dat  2.698915  3.347393
# 125         246  1028_associative_priming_part_1.dat  2.169789  1.669011
# 126         251  3034_associative_priming_part_1.dat  1.814959  1.770484
# 127         253  1005_associative_priming_part_1.dat  2.122660  1.649487
#
#       v3_mean   v4_mean   zr_mean    a_mean  ndt1_mean  ndt2_mean  ...  \
# ...
