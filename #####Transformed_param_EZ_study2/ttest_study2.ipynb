# %%
import pandas as pd
import pingouin as pg

def ttest(data_1,data_2) :
    df = pd.DataFrame([])
    for column in data_1 :
        if column == "Experiment":
            continue
        x1, x2 = data_1[column], data_2[column]
        x1_mean = x1.mean()
        x1_std = x1.std()
        x2_mean = x2.mean()
        x2_std = x2.std()

        res = pg.ttest(x1, x2, paired=True)
        res.insert(loc=0, column='parameter', value=column)
        res.insert(loc=1,column='mean_s1',value=x1_mean)
        res.insert(loc=2,column='std_s1',value=x1_std)
        res.insert(loc=3,column='mean_s2',value=x2_mean)
        res.insert(loc=4,column='std_s2',value=x2_std)

        df = df.append(res)



    df = df.round(4)
    return(df)
# Out:
# /home/m.ebrahimi/.conda/envs/m_base/lib/python3.10/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.3, the latest is 0.5.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
col= ['v1_mean',
 'v2_mean',
 'v3_mean',
 'v4_mean',
 'a_mean',
 'ndt1_mean',
 'ndt2_mean',
 'ndt3_mean',
 'ndt4_mean',
 'alpha_mean',
    'accuracy_percentage',
    'mean_log_rt',
    'alpha_mean_boxcox_after_arcsin',
    'accuracy_percentage_boxcox_after_arcsin'
                            ]
apt_s1 = pd.read_csv('EZ_associative_learning_transformed_part_1.csv').sort_values(by=['ID'], ascending=False)[col]
apt_s2 = pd.read_csv('EZ_associative_learning_transformed_part_2.csv').sort_values(by=['ID'], ascending=False)[col]

# %%
apt_s1.insert(5, "v_total = (v2 + v1)-(v3+v4)", (apt_s1['v1_mean']+apt_s1['v2_mean'])-(apt_s1['v3_mean']+apt_s1['v4_mean']), True)
apt_s1.insert(6, "v_bias = (v2 + v1)+ (v3+v4)", (apt_s1['v1_mean']+apt_s1['v2_mean'])+(apt_s1['v3_mean']+apt_s1['v4_mean']), True)
apt_s1.insert(7, "v_w_priming = (v2 - v1)", (apt_s1['v1_mean']-apt_s1['v2_mean']), True)
apt_s1.insert(8, "v_nw_priming = (v4 - v3)", (apt_s1['v4_mean']-apt_s1['v3_mean']), True)

# %%
apt_s2.insert(5, "v_total = (v2 + v1)-(v3+v4)", (apt_s2['v1_mean']+apt_s2['v2_mean'])-(apt_s2['v3_mean']+apt_s2['v4_mean']), True)
apt_s2.insert(6, "v_bias = (v2 + v1)+ (v3+v4)", (apt_s2['v1_mean']+apt_s2['v2_mean'])+(apt_s2['v3_mean']+apt_s2['v4_mean']), True)
apt_s2.insert(7, "v_w_priming = (v2 - v1)", (apt_s2['v1_mean']-apt_s2['v2_mean']), True)
apt_s2.insert(8, "v_nw_priming = (v4 - v3)", (apt_s2['v4_mean']-apt_s2['v3_mean']), True)

# %%
Ttest_apt = ttest (apt_s1,apt_s2)
Ttest_apt
# Out:
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
# /tmp/ipykernel_306356/2496601310.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(res)
#                                       parameter  mean_s1  std_s1  mean_s2  \
# T-test                                  v1_mean   2.1951  0.5004   2.3903
# T-test                                  v2_mean   2.0235  0.4355   2.2222
# T-test                                  v3_mean  -2.1175  0.5186  -2.3421
# T-test                                  v4_mean  -2.1191  0.5013  -2.3860
# T-test                                   a_mean   1.3903  0.3302   1.2257
# T-test              v_total = (v2 + v1)-(v3+v4)   8.4551  1.7639   9.3405
# T-test              v_bias = (v2 + v1)+ (v3+v4)  -0.0180  0.6431  -0.1156
# T-test                  v_w_priming = (v2 - v1)   0.1716  0.3068   0.1681
# T-test                 v_nw_priming = (v4 - v3)  -0.0016  0.2532  -0.0439
# T-test                                ndt1_mean   0.4661  0.0489   0.4582
# T-test                                ndt2_mean   0.5009  0.0498   0.4940
# T-test                                ndt3_mean   0.5583  0.0521   0.5300
# T-test                                ndt4_mean   0.5388  0.0536   0.5156
# T-test                               alpha_mean   1.7391  0.2059   1.7322
# T-test                      accuracy_percentage   0.9341  0.0419   0.9338
# T-test                              mean_log_rt   6.6997  0.1168   6.6038
# T-test           alpha_mean_boxcox_after_arcsin   0.0972  0.2311   0.0793
# T-test  accuracy_percentage_boxcox_after_arcsin   0.5651  0.1976   0.6786
#
#         std_s2        T  dof alternative   p-val           CI95%  cohen-d  \
# T-test  0.6130  -4.9607  127   two-sided  0.0000  [-0.27, -0.12]   0.3489
# T-test  0.5592  -5.8193  127   two-sided  0.0000  [-0.27, -0.13]   0.3965
# T-test  0.6120   5.7873  127   two-sided  0.0000     [0.15, 0.3]   0.3959
# T-test  0.5688   6.8928  127   two-sided  0.0000    [0.19, 0.34]   0.4978
# T-test  0.3047   9.3416  127   two-sided  0.0000     [0.13, 0.2]   0.5181
# T-test  2.1554  -7.4503  127   two-sided  0.0000  [-1.12, -0.65]   0.4496
# T-test  0.6921   1.5796  127   two-sided  0.1167   [-0.02, 0.22]   0.1461
# T-test  0.3116   0.1002  127   two-sided  0.9204   [-0.07, 0.07]   0.0112
# T-test  0.3372   1.1872  127   two-sided  0.2374   [-0.03, 0.11]   0.1419
# T-test  0.0485   1.9334  127   two-sided  0.0554    [-0.0, 0.02]   0.1607
# T-test  0.0422   1.7769  127   two-sided  0.0780    [-0.0, 0.01]   0.1490
# T-test  0.0452   7.6518  127   two-sided  0.0000    [0.02, 0.04]   0.5811
# T-test  0.0459   5.4043  127   two-sided  0.0000    [0.01, 0.03]   0.4650
# T-test  0.1962   0.5170  127   two-sided  0.6061   [-0.02, 0.03]   0.0346
# T-test  0.0499   0.1232  127   two-sided  0.9022     [-0.0, 0.0]   0.0061
# T-test  0.1066  15.8816  127   two-sided  0.0000    [0.08, 0.11]   0.8574
# T-test  0.2248   1.1328  127   two-sided  0.2594   [-0.01, 0.05]   0.0782
# T-test  0.2747  -8.5198  127   two-sided  0.0000  [-0.14, -0.09]   0.4741
#
#              BF10   power
# T-test   6029.896  0.9748
# T-test   2.43e+05  0.9936
# T-test  2.103e+05  0.9935
# T-test   3.92e+07  0.9999
# T-test  1.468e+13  0.9999
# T-test  6.441e+08  0.9990
# T-test      0.329  0.3746
# T-test      0.099  0.0518
# T-test      0.195  0.3571
# T-test      0.596  0.4381
# T-test      0.452  0.3871
# T-test  1.811e+09  1.0000
# T-test  3.887e+04  0.9994
# T-test      0.112  0.0675
# T-test      0.099  0.0505
# T-test  5.196e+28  1.0000
# T-test      0.184  0.1420
# T-test  1.731e+11  0.9996

# %%
Ttest_apt.to_csv('EZ_ttest_study2_apt_task.csv')
