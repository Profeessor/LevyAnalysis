# %%
import pandas as pd

# %%
apt_s1 = pd.read_csv('Distinct_APT_s1_correlation_matrix.csv')
apt_s2 = pd.read_csv('Distinct_APT_s2_correlation_matrix.csv')
apt_s1
# Out:
#        Unnamed: 0        v1        v2        v3        v4        zr         a  \
# 0              v1       NaN  0.811411 -0.552538 -0.572278 -0.472533  0.088523
# 1              v2  0.811411       NaN -0.586018 -0.550648 -0.518992  0.302157
# 2              v3 -0.552538 -0.586018       NaN  0.852226  0.060542 -0.172219
# 3              v4 -0.572278 -0.550648  0.852226       NaN -0.009488 -0.125108
# 4              zr -0.472533 -0.518992  0.060542 -0.009488       NaN -0.255368
# 5               a  0.088523  0.302157 -0.172219 -0.125108 -0.255368       NaN
# 6            ndt1  0.017366 -0.041346 -0.042138 -0.020985  0.009348  0.114676
# 7            ndt2 -0.014895  0.037140 -0.108154 -0.088236  0.048264  0.116802
# 8            ndt3  0.138517  0.205080 -0.129189 -0.038042 -0.447354  0.298970
# 9            ndt4  0.099597  0.165615 -0.075202 -0.115834 -0.436386  0.299719
# 10           sndt -0.264301 -0.268570  0.183222  0.185299  0.088278 -0.254742
# ...

# %%
sum=apt_s1+apt_s2
sum['Unnamed: 0'] = apt_s1['Unnamed: 0']
ave=sum.loc[:,sum.columns != 'Unnamed: 0']/2
idx = 0 
ave.insert(loc=idx, column='par', value=apt_s1['Unnamed: 0'])

# %%
ave
# Out:
#               par        v1        v2        v3        v4        zr         a  \
# 0              v1       NaN  0.831436 -0.586615 -0.611592 -0.409813  0.162048
# 1              v2  0.831436       NaN -0.614521 -0.599041 -0.454772  0.338060
# 2              v3 -0.586615 -0.614521       NaN  0.838116 -0.019944 -0.201095
# 3              v4 -0.611592 -0.599041  0.838116       NaN -0.056566 -0.199528
# 4              zr -0.409813 -0.454772 -0.019944 -0.056566       NaN -0.229216
# 5               a  0.162048  0.338060 -0.201095 -0.199528 -0.229216       NaN
# 6            ndt1  0.009615 -0.036019 -0.055429 -0.046332  0.040504  0.154094
# 7            ndt2  0.011948  0.067485 -0.155217 -0.146069  0.082553  0.155534
# 8            ndt3  0.135983  0.169762 -0.131084 -0.048288 -0.315699  0.315641
# 9            ndt4  0.118409  0.156113 -0.072610 -0.139742 -0.323541  0.325249
# 10           sndt -0.360703 -0.417295  0.313750  0.268535  0.181438 -0.325277
# ...

# %%
ave = ave.fillna(1)
ave= ave.round(3)

ave.to_csv('Study_2_average_distinct_correlation_across_2_data.csv')
